# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %%
kill.dropna(how="any",inplace=True)

# %%
kill.shape
# Out:
# (2254, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.manner_of_death.value_counts().index
# Out:
# Index(['shot', 'shot and Tasered'], dtype='object')

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(x = "gender", y = "age", hue="manner_of_death",data=kill)
plt.show()

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn
plt.figure(figsize=(10,6))
sns.swarmplot(x ="gender", y = "age", hue="manner_of_death", data=kill)
plt.show()

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
a = kill.city.value_counts()[:12]
a
# Out:
# Los Angeles      35
# Phoenix          28
# Houston          24
# Chicago          22
# Austin           18
# Las Vegas        17
# Columbus         16
# Miami            15
# San Antonio      15
# Indianapolis     14
# St. Louis        14
# Oklahoma City    13
# Name: city, dtype: int64

# %%
# with seaborn barplot
plt.figure(figsize=(8,5))
sns.barplot(x=a.index,y=a,data=kill)
plt.xticks(rotation=45)
plt.title("Most dangerous cities", color="purple")
plt.ylabel(" ")
plt.show()

# %%
# with seaborn countplot
plt.figure(figsize=(8,5))
sns.countplot(x =kill.city,order=kill.city.value_counts()[:12].index)
plt.title("Most dangerous cities", color="purple")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state = kill.state.value_counts()[:20]
state
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# TN     56
# IL     56
# WA     51
# LA     47
# PA     45
# AL     45
# NY     43
# VA     43
# WI     42
# SC     41
# Name: state, dtype: int64

# %%
# with seaborn barplot
plt.figure(figsize=(8,5))
axes = sns.barplot(x=state.index,y = state.values)
plt.title("Most dangerous states",color="#af1050")
plt.xticks(rotation=45)
for i in axes.patches:
    axes.annotate(i.get_height(), (i.get_x()+0.03,i.get_height()+5.5),rotation=75) 
plt.show()

# %%
# with seaborn countplot
plt.figure(figsize =(8,5))
sns.countplot(x=kill.state,order=kill.state.value_counts()[:20].index)
plt.title("Most Dangerous States",color="red")
plt.xticks(rotation=60)


plt.show()

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.signs_of_mental_illness.value_counts()
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn
sns.countplot(x=kill.signs_of_mental_illness);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
kill.sample()
# Out:
#         id              name      date manner_of_death    armed   age gender  \
# 1496  1691  Pedro Villanueva  03/07/16            shot  vehicle  19.0      M
#
#      race       city state  signs_of_mental_illness threat_level flee  \
# 1496    H  Fullerton    CA                    False        other  Car
#
#       body_camera
# 1496        False

# %%
kill.threat_level.value_counts()
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
# with seaborn
sns.countplot(x=kill.threat_level)
plt.title("Threat Level",color="blue")
plt.show()

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
kill.flee.value_counts()
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
# with seaborn
sns.countplot(x=kill.flee)
plt.title("Flee Types",color="green")
plt.
plt.show()
# Out:
# No handles with labels found to put in legend.
